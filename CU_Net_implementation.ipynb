# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **mio**

# %%
def getConvBlockOne(layerPrec, filters, kernel_size = (1, 1), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getConvBlockTwo(layerPrec, filters, kernel_size = (3, 3), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getUNet(input, shape, filters):
    # CONTRACTING PHASE
  # RED block
  l1 = getConvBlockOne(input,filters)
  l1 = getConvBlockTwo(l1,filters)
  # ---
  concat1 = Concatenate()([l1,input])
  # ORANGE block
  middle1 = getConvBlockOne(concat1,filters)

  # GREEN block
  l2 = getConvBlockOne(concat1,filters)
  maxPooling1 = MaxPool2D(padding='same')(l2)
  # ---

    # Bottle neck
  l3 = getConvBlockOne(maxPooling1,filters)
  l4 = getConvBlockTwo(l3,filters)
  concat2 = Concatenate()([maxPooling1,l4])

    # EXPANSIVE PATH
  # BLUE block
  l5 = getConvBlockOne(concat2,filters)
  layer = UpSampling2D()(l5)
  layer = Conv2D(filters, kernel_size=(2,2), activation='relu', kernel_initializer='he_normal', padding='same')(layer)
  layer = BatchNormalization()(layer)
  # ---
  concat3 = Concatenate()([middle1,layer])
  
  l6 = getConvBlockOne(concat3,filters)
  l7 = getConvBlockTwo(l6,filters)
  concat4 = Concatenate()([concat3,l7])
  output = getConvBlockOne(concat4,filters)
  return Model(inputs=input, outputs=output)

def getModel(shape=(128, 128, 3), filters=64):
  # m: main feature flow
  # n: generated feature number in a block of U-Net

  input = Input(shape=shape)
  output = getUNet(input, shape, filters=64)
  return output

# %%
net = getModel(shape=(128,128,3), filters=32)
net.summary()

# %%
def getUnit1(layerPrec, filters, kernel_size = (1, 1), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getUnit2(layerPrec, filters, kernel_size = (3, 3), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getDownBlock(layerPrec,m,n,indexBlock):
  l = getUnit1(layerPrec,4*n)
  l = getUnit2(l,n)
  nets["layers"][f"down{indexBlock}"].append(l)

  concat = Concatenate()([layerPrec,l])
  l = getUnit1(concat,m)
  maxPooling = MaxPool2D(padding='same')(l)
  return maxPooling, getUnit1(concat,m)

def getUpBlock(layerPrec,skipConn,m,n,indexBlock,upLayers=[]):
  l = getUnit1(layerPrec,m)
  l = UpSampling2D()(layerPrec)
  concat = Concatenate()([skipConn,l]+upLayers)
  l = getUnit1(concat,4*n)
  l = getUnit2(l,n)
  nets["layers"][f"up{indexBlock}"].append(l)
  concat = Concatenate()([concat,l])
  return concat

def getUNet(input,m,n,indexUNet,nUNet, nBlocks):
  layerPrec = input
  listSkipConn = []

  if indexUNet != 0:
    layerPrec = nets[f"unet{indexUNet-1}"]
    #layerPrec = Concatenate()([input,layerPrec]) #l'abbiamo fatto giù con l'if dopo l'up
    layerPrec = getUnit1(layerPrec,m)

  # down
  for i in range(nBlocks):
    layerPrec = Concatenate()([layerPrec]+nets["layers"][f"down{i}"])
    layerPrec, skipConn = getDownBlock(layerPrec,m,n,i)
    listSkipConn.append(skipConn)

  # bottle neck
  layerPrec = Concatenate()([layerPrec]+nets["layers"][f"bn"])

  l = getUnit1(layerPrec,4*n)
  l = getUnit2(l,n)
  nets["layers"]["bn"].append(l)
  concat = Concatenate()([layerPrec,l])

  # up
  layerPrec = concat
  for i in range(nBlocks):
    layerPrec = getUpBlock(layerPrec,listSkipConn[-(i+1)],m,n,i,upLayers=nets["layers"][f"up{i}"])


  if indexUNet != nUNet - 1:
    l = Concatenate()([input,layerPrec])
  else:
    l = getUnit1(layerPrec,16,activation=None)

  return l

def trasformationInput(x, filters):
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters, kernel_size=(7,7), strides=(2,2), kernel_initializer='he_normal', padding='same')(x)
  maxPooling = MaxPool2D(padding='same')(x)
  return maxPooling

def getCUNet(shape,m,n,nUNet,nBlocks):
  for i in range(nUNet):
    nets[f"unet{i}"] = None

  for j in range(nBlocks):
    nets["layers"][f"down{j}"] = []
    nets["layers"][f"up{j}"] = []
    
  input = Input(shape=shape)
  
  input = trasformationInput(input,m) # per le heatmap da 64x64
  print(input.shape)
  for i in range(nUNet):
    nets[f"unet{i}"] = getUNet(input,m,n,i,nUNet,nBlocks)

  output = nets[f"unet{nUNet-1}"]
  return Model(inputs=input, outputs=output)

nets = {}
nets["layers"] = {}
nets["layers"]["bn"] = []
shape = (256,256,3)
m = 64
n = 16
nUNet = 4
nBlocks = 4
net = getCUNet(shape,m,n,nUNet,nBlocks)
net.summary()
# Out:
# (None, 64, 64, 64)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 64, 64, 64)  0           []
#                                 ]
#
#  concatenate_514 (Concatenate)  (None, 64, 64, 64)   0           ['input_19[0][0]']
#
#  batch_normalization_845 (Batch  (None, 64, 64, 64)  256         ['concatenate_514[1][0]']
#  Normalization)
#
#  activation_845 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_845[1][0]']
#
#  conv2d_844 (Conv2D)            (None, 64, 64, 64)   4160        ['activation_845[1][0]']
#
#  batch_normalization_846 (Batch  (None, 64, 64, 64)  256         ['conv2d_844[1][0]']
#  Normalization)
#
#  activation_846 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_846[1][0]']
#
#  conv2d_845 (Conv2D)            (None, 64, 64, 16)   9232        ['activation_846[1][0]']
#
#  concatenate_515 (Concatenate)  (None, 64, 64, 80)   0           ['concatenate_514[1][0]',
#                                                                   'conv2d_845[1][0]']
#
#  batch_normalization_847 (Batch  (None, 64, 64, 80)  320         ['concatenate_515[1][0]']
#  Normalization)
#
#  activation_847 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_847[1][0]']
#
#  conv2d_846 (Conv2D)            (None, 64, 64, 64)   5184        ['activation_847[1][0]']
#
#  max_pooling2d_123 (MaxPooling2  (None, 32, 32, 64)  0           ['conv2d_846[1][0]']
#  D)
#
#  concatenate_516 (Concatenate)  (None, 32, 32, 64)   0           ['max_pooling2d_123[1][0]']
#
#  batch_normalization_849 (Batch  (None, 32, 32, 64)  256         ['concatenate_516[1][0]']
#  Normalization)
#
#  activation_849 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_849[1][0]']
#
#  conv2d_848 (Conv2D)            (None, 32, 32, 64)   4160        ['activation_849[1][0]']
#
#  batch_normalization_850 (Batch  (None, 32, 32, 64)  256         ['conv2d_848[1][0]']
#  Normalization)
#
#  activation_850 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_850[1][0]']
#
#  conv2d_849 (Conv2D)            (None, 32, 32, 16)   9232        ['activation_850[1][0]']
#
#  concatenate_517 (Concatenate)  (None, 32, 32, 80)   0           ['concatenate_516[1][0]',
#                                                                   'conv2d_849[1][0]']
#
#  batch_normalization_851 (Batch  (None, 32, 32, 80)  320         ['concatenate_517[1][0]']
#  Normalization)
#
#  activation_851 (Activation)    (None, 32, 32, 80)   0           ['batch_normalization_851[1][0]']
#
#  conv2d_850 (Conv2D)            (None, 32, 32, 64)   5184        ['activation_851[1][0]']
#
#  max_pooling2d_124 (MaxPooling2  (None, 16, 16, 64)  0           ['conv2d_850[1][0]']
#  D)
#
#  concatenate_518 (Concatenate)  (None, 16, 16, 64)   0           ['max_pooling2d_124[1][0]']
#
#  batch_normalization_853 (Batch  (None, 16, 16, 64)  256         ['concatenate_518[1][0]']
#  Normalization)
#
#  activation_853 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_853[1][0]']
#
#  conv2d_852 (Conv2D)            (None, 16, 16, 64)   4160        ['activation_853[1][0]']
#
#  batch_normalization_854 (Batch  (None, 16, 16, 64)  256         ['conv2d_852[1][0]']
#  Normalization)
#
#  activation_854 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_854[1][0]']
#
#  conv2d_853 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_854[1][0]']
#
#  concatenate_519 (Concatenate)  (None, 16, 16, 80)   0           ['concatenate_518[1][0]',
#                                                                   'conv2d_853[1][0]']
#
#  batch_normalization_855 (Batch  (None, 16, 16, 80)  320         ['concatenate_519[1][0]']
#  Normalization)
#
#  activation_855 (Activation)    (None, 16, 16, 80)   0           ['batch_normalization_855[1][0]']
#
#  conv2d_854 (Conv2D)            (None, 16, 16, 64)   5184        ['activation_855[1][0]']
#
#  max_pooling2d_125 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_854[1][0]']
#  D)
#
#  concatenate_520 (Concatenate)  (None, 8, 8, 64)     0           ['max_pooling2d_125[1][0]']
#
#  batch_normalization_857 (Batch  (None, 8, 8, 64)    256         ['concatenate_520[1][0]']
#  Normalization)
#
#  activation_857 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_857[1][0]']
#
#  conv2d_856 (Conv2D)            (None, 8, 8, 64)     4160        ['activation_857[1][0]']
#
#  batch_normalization_858 (Batch  (None, 8, 8, 64)    256         ['conv2d_856[1][0]']
#  Normalization)
#
#  activation_858 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_858[1][0]']
#
#  conv2d_857 (Conv2D)            (None, 8, 8, 16)     9232        ['activation_858[1][0]']
#
#  concatenate_521 (Concatenate)  (None, 8, 8, 80)     0           ['concatenate_520[1][0]',
#                                                                   'conv2d_857[1][0]']
#
#  batch_normalization_859 (Batch  (None, 8, 8, 80)    320         ['concatenate_521[1][0]']
#  Normalization)
#
#  activation_859 (Activation)    (None, 8, 8, 80)     0           ['batch_normalization_859[1][0]']
#
#  conv2d_858 (Conv2D)            (None, 8, 8, 64)     5184        ['activation_859[1][0]']
#
#  max_pooling2d_126 (MaxPooling2  (None, 4, 4, 64)    0           ['conv2d_858[1][0]']
#  D)
#
#  concatenate_522 (Concatenate)  (None, 4, 4, 64)     0           ['max_pooling2d_126[1][0]']
#
#  batch_normalization_861 (Batch  (None, 4, 4, 64)    256         ['concatenate_522[1][0]']
#  Normalization)
#
#  activation_861 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_861[1][0]']
#
#  conv2d_860 (Conv2D)            (None, 4, 4, 64)     4160        ['activation_861[1][0]']
#
#  batch_normalization_862 (Batch  (None, 4, 4, 64)    256         ['conv2d_860[1][0]']
#  Normalization)
#
#  activation_862 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_862[1][0]']
#
#  batch_normalization_860 (Batch  (None, 8, 8, 80)    320         ['concatenate_521[1][0]']
#  Normalization)
#
#  conv2d_861 (Conv2D)            (None, 4, 4, 16)     9232        ['activation_862[1][0]']
#
#  activation_860 (Activation)    (None, 8, 8, 80)     0           ['batch_normalization_860[1][0]']
#
#  concatenate_523 (Concatenate)  (None, 4, 4, 80)     0           ['concatenate_522[1][0]',
#                                                                   'conv2d_861[1][0]']
#
#  conv2d_859 (Conv2D)            (None, 8, 8, 64)     5184        ['activation_860[1][0]']
#
#  up_sampling2d_109 (UpSampling2  (None, 8, 8, 80)    0           ['concatenate_523[1][0]']
#  D)
#
#  concatenate_524 (Concatenate)  (None, 8, 8, 144)    0           ['conv2d_859[1][0]',
#                                                                   'up_sampling2d_109[1][0]']
#
#  batch_normalization_864 (Batch  (None, 8, 8, 144)   576         ['concatenate_524[1][0]']
#  Normalization)
#
#  activation_864 (Activation)    (None, 8, 8, 144)    0           ['batch_normalization_864[1][0]']
#
#  conv2d_863 (Conv2D)            (None, 8, 8, 64)     9280        ['activation_864[1][0]']
#
#  batch_normalization_865 (Batch  (None, 8, 8, 64)    256         ['conv2d_863[1][0]']
#  Normalization)
#
#  activation_865 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_865[1][0]']
#
#  batch_normalization_856 (Batch  (None, 16, 16, 80)  320         ['concatenate_519[1][0]']
#  Normalization)
#
#  conv2d_864 (Conv2D)            (None, 8, 8, 16)     9232        ['activation_865[1][0]']
#
#  activation_856 (Activation)    (None, 16, 16, 80)   0           ['batch_normalization_856[1][0]']
#
#  concatenate_525 (Concatenate)  (None, 8, 8, 160)    0           ['concatenate_524[1][0]',
#                                                                   'conv2d_864[1][0]']
#
#  conv2d_855 (Conv2D)            (None, 16, 16, 64)   5184        ['activation_856[1][0]']
#
#  up_sampling2d_110 (UpSampling2  (None, 16, 16, 160)  0          ['concatenate_525[1][0]']
#  D)
#
#  concatenate_526 (Concatenate)  (None, 16, 16, 224)  0           ['conv2d_855[1][0]',
#                                                                   'up_sampling2d_110[1][0]']
#
#  batch_normalization_867 (Batch  (None, 16, 16, 224)  896        ['concatenate_526[1][0]']
#  Normalization)
#
#  activation_867 (Activation)    (None, 16, 16, 224)  0           ['batch_normalization_867[1][0]']
#
#  conv2d_866 (Conv2D)            (None, 16, 16, 64)   14400       ['activation_867[1][0]']
#
#  batch_normalization_868 (Batch  (None, 16, 16, 64)  256         ['conv2d_866[1][0]']
#  Normalization)
#
#  activation_868 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_868[1][0]']
#
#  batch_normalization_852 (Batch  (None, 32, 32, 80)  320         ['concatenate_517[1][0]']
#  Normalization)
#
#  conv2d_867 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_868[1][0]']
#
#  activation_852 (Activation)    (None, 32, 32, 80)   0           ['batch_normalization_852[1][0]']
#
#  concatenate_527 (Concatenate)  (None, 16, 16, 240)  0           ['concatenate_526[1][0]',
#                                                                   'conv2d_867[1][0]']
#
#  conv2d_851 (Conv2D)            (None, 32, 32, 64)   5184        ['activation_852[1][0]']
#
#  up_sampling2d_111 (UpSampling2  (None, 32, 32, 240)  0          ['concatenate_527[1][0]']
#  D)
#
#  concatenate_528 (Concatenate)  (None, 32, 32, 304)  0           ['conv2d_851[1][0]',
#                                                                   'up_sampling2d_111[1][0]']
#
#  batch_normalization_870 (Batch  (None, 32, 32, 304)  1216       ['concatenate_528[1][0]']
#  Normalization)
#
#  activation_870 (Activation)    (None, 32, 32, 304)  0           ['batch_normalization_870[1][0]']
#
#  conv2d_869 (Conv2D)            (None, 32, 32, 64)   19520       ['activation_870[1][0]']
#
#  batch_normalization_871 (Batch  (None, 32, 32, 64)  256         ['conv2d_869[1][0]']
#  Normalization)
#
#  activation_871 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_871[1][0]']
#
#  batch_normalization_848 (Batch  (None, 64, 64, 80)  320         ['concatenate_515[1][0]']
#  Normalization)
#
#  conv2d_870 (Conv2D)            (None, 32, 32, 16)   9232        ['activation_871[1][0]']
#
#  activation_848 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_848[1][0]']
#
#  concatenate_529 (Concatenate)  (None, 32, 32, 320)  0           ['concatenate_528[1][0]',
#                                                                   'conv2d_870[1][0]']
#
#  conv2d_847 (Conv2D)            (None, 64, 64, 64)   5184        ['activation_848[1][0]']
#
#  up_sampling2d_112 (UpSampling2  (None, 64, 64, 320)  0          ['concatenate_529[1][0]']
#  D)
#
#  concatenate_530 (Concatenate)  (None, 64, 64, 384)  0           ['conv2d_847[1][0]',
#                                                                   'up_sampling2d_112[1][0]']
#
#  batch_normalization_873 (Batch  (None, 64, 64, 384)  1536       ['concatenate_530[1][0]']
#  Normalization)
#
#  activation_873 (Activation)    (None, 64, 64, 384)  0           ['batch_normalization_873[1][0]']
#
#  conv2d_872 (Conv2D)            (None, 64, 64, 64)   24640       ['activation_873[1][0]']
#
#  batch_normalization_874 (Batch  (None, 64, 64, 64)  256         ['conv2d_872[1][0]']
#  Normalization)
#
#  activation_874 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_874[1][0]']
#
#  conv2d_873 (Conv2D)            (None, 64, 64, 16)   9232        ['activation_874[1][0]']
#
#  concatenate_531 (Concatenate)  (None, 64, 64, 400)  0           ['concatenate_530[1][0]',
#                                                                   'conv2d_873[1][0]']
#
#  concatenate_532 (Concatenate)  (None, 64, 64, 464)  0           ['input_19[0][0]',
#                                                                   'concatenate_531[1][0]']
#
#  batch_normalization_875 (Batch  (None, 64, 64, 464)  1856       ['concatenate_532[1][0]']
#  Normalization)
#
#  activation_875 (Activation)    (None, 64, 64, 464)  0           ['batch_normalization_875[1][0]']
#
#  conv2d_874 (Conv2D)            (None, 64, 64, 64)   29760       ['activation_875[1][0]']
#
#  concatenate_533 (Concatenate)  (None, 64, 64, 80)   0           ['conv2d_874[1][0]',
#                                                                   'conv2d_845[1][0]']
#
#  batch_normalization_876 (Batch  (None, 64, 64, 80)  320         ['concatenate_533[1][0]']
#  Normalization)
#
#  activation_876 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_876[1][0]']
#
#  conv2d_875 (Conv2D)            (None, 64, 64, 64)   5184        ['activation_876[1][0]']
#
#  batch_normalization_877 (Batch  (None, 64, 64, 64)  256         ['conv2d_875[1][0]']
#  Normalization)
#
#  activation_877 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_877[1][0]']
#
#  conv2d_876 (Conv2D)            (None, 64, 64, 16)   9232        ['activation_877[1][0]']
#
#  concatenate_534 (Concatenate)  (None, 64, 64, 96)   0           ['concatenate_533[1][0]',
#                                                                   'conv2d_876[1][0]']
#
#  batch_normalization_878 (Batch  (None, 64, 64, 96)  384         ['concatenate_534[1][0]']
#  Normalization)
#
#  activation_878 (Activation)    (None, 64, 64, 96)   0           ['batch_normalization_878[1][0]']
#
#  conv2d_877 (Conv2D)            (None, 64, 64, 64)   6208        ['activation_878[1][0]']
#
#  max_pooling2d_127 (MaxPooling2  (None, 32, 32, 64)  0           ['conv2d_877[1][0]']
#  D)
#
#  concatenate_535 (Concatenate)  (None, 32, 32, 80)   0           ['max_pooling2d_127[1][0]',
#                                                                   'conv2d_849[1][0]']
#
#  batch_normalization_880 (Batch  (None, 32, 32, 80)  320         ['concatenate_535[1][0]']
#  Normalization)
#
#  activation_880 (Activation)    (None, 32, 32, 80)   0           ['batch_normalization_880[1][0]']
#
#  conv2d_879 (Conv2D)            (None, 32, 32, 64)   5184        ['activation_880[1][0]']
#
#  batch_normalization_881 (Batch  (None, 32, 32, 64)  256         ['conv2d_879[1][0]']
#  Normalization)
#
#  activation_881 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_881[1][0]']
#
#  conv2d_880 (Conv2D)            (None, 32, 32, 16)   9232        ['activation_881[1][0]']
#
#  concatenate_536 (Concatenate)  (None, 32, 32, 96)   0           ['concatenate_535[1][0]',
#                                                                   'conv2d_880[1][0]']
#
#  batch_normalization_882 (Batch  (None, 32, 32, 96)  384         ['concatenate_536[1][0]']
#  Normalization)
#
#  activation_882 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_882[1][0]']
#
#  conv2d_881 (Conv2D)            (None, 32, 32, 64)   6208        ['activation_882[1][0]']
#
#  max_pooling2d_128 (MaxPooling2  (None, 16, 16, 64)  0           ['conv2d_881[1][0]']
#  D)
#
#  concatenate_537 (Concatenate)  (None, 16, 16, 80)   0           ['max_pooling2d_128[1][0]',
#                                                                   'conv2d_853[1][0]']
#
#  batch_normalization_884 (Batch  (None, 16, 16, 80)  320         ['concatenate_537[1][0]']
#  Normalization)
#
#  activation_884 (Activation)    (None, 16, 16, 80)   0           ['batch_normalization_884[1][0]']
#
#  conv2d_883 (Conv2D)            (None, 16, 16, 64)   5184        ['activation_884[1][0]']
#
#  batch_normalization_885 (Batch  (None, 16, 16, 64)  256         ['conv2d_883[1][0]']
#  Normalization)
#
#  activation_885 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_885[1][0]']
#
#  conv2d_884 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_885[1][0]']
#
#  concatenate_538 (Concatenate)  (None, 16, 16, 96)   0           ['concatenate_537[1][0]',
#                                                                   'conv2d_884[1][0]']
#
#  batch_normalization_886 (Batch  (None, 16, 16, 96)  384         ['concatenate_538[1][0]']
#  Normalization)
#
#  activation_886 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_886[1][0]']
#
#  conv2d_885 (Conv2D)            (None, 16, 16, 64)   6208        ['activation_886[1][0]']
#
#  max_pooling2d_129 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_885[1][0]']
#  D)
#
#  concatenate_539 (Concatenate)  (None, 8, 8, 80)     0           ['max_pooling2d_129[1][0]',
#                                                                   'conv2d_857[1][0]']
#
#  batch_normalization_888 (Batch  (None, 8, 8, 80)    320         ['concatenate_539[1][0]']
#  Normalization)
#
#  activation_888 (Activation)    (None, 8, 8, 80)     0           ['batch_normalization_888[1][0]']
#
#  conv2d_887 (Conv2D)            (None, 8, 8, 64)     5184        ['activation_888[1][0]']
#
#  batch_normalization_889 (Batch  (None, 8, 8, 64)    256         ['conv2d_887[1][0]']
#  Normalization)
#
#  activation_889 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_889[1][0]']
#
#  conv2d_888 (Conv2D)            (None, 8, 8, 16)     9232        ['activation_889[1][0]']
#
#  concatenate_540 (Concatenate)  (None, 8, 8, 96)     0           ['concatenate_539[1][0]',
#                                                                   'conv2d_888[1][0]']
#
#  batch_normalization_890 (Batch  (None, 8, 8, 96)    384         ['concatenate_540[1][0]']
#  Normalization)
#
#  activation_890 (Activation)    (None, 8, 8, 96)     0           ['batch_normalization_890[1][0]']
#
#  conv2d_889 (Conv2D)            (None, 8, 8, 64)     6208        ['activation_890[1][0]']
#
#  max_pooling2d_130 (MaxPooling2  (None, 4, 4, 64)    0           ['conv2d_889[1][0]']
#  D)
#
#  concatenate_541 (Concatenate)  (None, 4, 4, 80)     0           ['max_pooling2d_130[1][0]',
#                                                                   'conv2d_861[1][0]']
#
#  batch_normalization_892 (Batch  (None, 4, 4, 80)    320         ['concatenate_541[1][0]']
#  Normalization)
#
#  activation_892 (Activation)    (None, 4, 4, 80)     0           ['batch_normalization_892[1][0]']
#
#  conv2d_891 (Conv2D)            (None, 4, 4, 64)     5184        ['activation_892[1][0]']
#
#  batch_normalization_893 (Batch  (None, 4, 4, 64)    256         ['conv2d_891[1][0]']
#  Normalization)
#
#  activation_893 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_893[1][0]']
#
#  batch_normalization_891 (Batch  (None, 8, 8, 96)    384         ['concatenate_540[1][0]']
#  Normalization)
#
#  conv2d_892 (Conv2D)            (None, 4, 4, 16)     9232        ['activation_893[1][0]']
#
#  activation_891 (Activation)    (None, 8, 8, 96)     0           ['batch_normalization_891[1][0]']
#
#  concatenate_542 (Concatenate)  (None, 4, 4, 96)     0           ['concatenate_541[1][0]',
#                                                                   'conv2d_892[1][0]']
#
#  conv2d_890 (Conv2D)            (None, 8, 8, 64)     6208        ['activation_891[1][0]']
#
#  up_sampling2d_113 (UpSampling2  (None, 8, 8, 96)    0           ['concatenate_542[1][0]']
#  D)
#
#  concatenate_543 (Concatenate)  (None, 8, 8, 176)    0           ['conv2d_890[1][0]',
#                                                                   'up_sampling2d_113[1][0]',
#                                                                   'conv2d_864[1][0]']
#
#  batch_normalization_895 (Batch  (None, 8, 8, 176)   704         ['concatenate_543[1][0]']
#  Normalization)
#
#  activation_895 (Activation)    (None, 8, 8, 176)    0           ['batch_normalization_895[1][0]']
#
#  conv2d_894 (Conv2D)            (None, 8, 8, 64)     11328       ['activation_895[1][0]']
#
#  batch_normalization_896 (Batch  (None, 8, 8, 64)    256         ['conv2d_894[1][0]']
#  Normalization)
#
#  activation_896 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_896[1][0]']
#
#  batch_normalization_887 (Batch  (None, 16, 16, 96)  384         ['concatenate_538[1][0]']
#  Normalization)
#
#  conv2d_895 (Conv2D)            (None, 8, 8, 16)     9232        ['activation_896[1][0]']
#
#  activation_887 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_887[1][0]']
#
#  concatenate_544 (Concatenate)  (None, 8, 8, 192)    0           ['concatenate_543[1][0]',
#                                                                   'conv2d_895[1][0]']
#
#  conv2d_886 (Conv2D)            (None, 16, 16, 64)   6208        ['activation_887[1][0]']
#
#  up_sampling2d_114 (UpSampling2  (None, 16, 16, 192)  0          ['concatenate_544[1][0]']
#  D)
#
#  concatenate_545 (Concatenate)  (None, 16, 16, 272)  0           ['conv2d_886[1][0]',
#                                                                   'up_sampling2d_114[1][0]',
#                                                                   'conv2d_867[1][0]']
#
#  batch_normalization_898 (Batch  (None, 16, 16, 272)  1088       ['concatenate_545[1][0]']
#  Normalization)
#
#  activation_898 (Activation)    (None, 16, 16, 272)  0           ['batch_normalization_898[1][0]']
#
#  conv2d_897 (Conv2D)            (None, 16, 16, 64)   17472       ['activation_898[1][0]']
#
#  batch_normalization_899 (Batch  (None, 16, 16, 64)  256         ['conv2d_897[1][0]']
#  Normalization)
#
#  activation_899 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_899[1][0]']
#
#  batch_normalization_883 (Batch  (None, 32, 32, 96)  384         ['concatenate_536[1][0]']
#  Normalization)
#
#  conv2d_898 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_899[1][0]']
#
#  activation_883 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_883[1][0]']
#
#  concatenate_546 (Concatenate)  (None, 16, 16, 288)  0           ['concatenate_545[1][0]',
#                                                                   'conv2d_898[1][0]']
#
#  conv2d_882 (Conv2D)            (None, 32, 32, 64)   6208        ['activation_883[1][0]']
#
#  up_sampling2d_115 (UpSampling2  (None, 32, 32, 288)  0          ['concatenate_546[1][0]']
#  D)
#
#  concatenate_547 (Concatenate)  (None, 32, 32, 368)  0           ['conv2d_882[1][0]',
# ...
#                                                                   'conv2d_923[1][0]']
#
#  batch_normalization_954 (Batch  (None, 4, 4, 112)   448         ['concatenate_579[1][0]']
#  Normalization)
#
#  activation_954 (Activation)    (None, 4, 4, 112)    0           ['batch_normalization_954[1][0]']
#
#  conv2d_953 (Conv2D)            (None, 4, 4, 64)     7232        ['activation_954[1][0]']
#
#  batch_normalization_955 (Batch  (None, 4, 4, 64)    256         ['conv2d_953[1][0]']
#  Normalization)
#
#  activation_955 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_955[1][0]']
#
#  batch_normalization_953 (Batch  (None, 8, 8, 128)   512         ['concatenate_578[1][0]']
#  Normalization)
#
#  conv2d_954 (Conv2D)            (None, 4, 4, 16)     9232        ['activation_955[1][0]']
#
#  activation_953 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_953[1][0]']
#
#  concatenate_580 (Concatenate)  (None, 4, 4, 128)    0           ['concatenate_579[1][0]',
#                                                                   'conv2d_954[1][0]']
#
#  conv2d_952 (Conv2D)            (None, 8, 8, 64)     8256        ['activation_953[1][0]']
#
#  up_sampling2d_121 (UpSampling2  (None, 8, 8, 128)   0           ['concatenate_580[1][0]']
#  D)
#
#  concatenate_581 (Concatenate)  (None, 8, 8, 240)    0           ['conv2d_952[1][0]',
#                                                                   'up_sampling2d_121[1][0]',
#                                                                   'conv2d_864[1][0]',
#                                                                   'conv2d_895[1][0]',
#                                                                   'conv2d_926[1][0]']
#
#  batch_normalization_957 (Batch  (None, 8, 8, 240)   960         ['concatenate_581[1][0]']
#  Normalization)
#
#  activation_957 (Activation)    (None, 8, 8, 240)    0           ['batch_normalization_957[1][0]']
#
#  conv2d_956 (Conv2D)            (None, 8, 8, 64)     15424       ['activation_957[1][0]']
#
#  batch_normalization_958 (Batch  (None, 8, 8, 64)    256         ['conv2d_956[1][0]']
#  Normalization)
#
#  activation_958 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_958[1][0]']
#
#  batch_normalization_949 (Batch  (None, 16, 16, 128)  512        ['concatenate_576[1][0]']
#  Normalization)
#
#  conv2d_957 (Conv2D)            (None, 8, 8, 16)     9232        ['activation_958[1][0]']
#
#  activation_949 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_949[1][0]']
#
#  concatenate_582 (Concatenate)  (None, 8, 8, 256)    0           ['concatenate_581[1][0]',
#                                                                   'conv2d_957[1][0]']
#
#  conv2d_948 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_949[1][0]']
#
#  up_sampling2d_122 (UpSampling2  (None, 16, 16, 256)  0          ['concatenate_582[1][0]']
#  D)
#
#  concatenate_583 (Concatenate)  (None, 16, 16, 368)  0           ['conv2d_948[1][0]',
#                                                                   'up_sampling2d_122[1][0]',
#                                                                   'conv2d_867[1][0]',
#                                                                   'conv2d_898[1][0]',
#                                                                   'conv2d_929[1][0]']
#
#  batch_normalization_960 (Batch  (None, 16, 16, 368)  1472       ['concatenate_583[1][0]']
#  Normalization)
#
#  activation_960 (Activation)    (None, 16, 16, 368)  0           ['batch_normalization_960[1][0]']
#
#  conv2d_959 (Conv2D)            (None, 16, 16, 64)   23616       ['activation_960[1][0]']
#
#  batch_normalization_961 (Batch  (None, 16, 16, 64)  256         ['conv2d_959[1][0]']
#  Normalization)
#
#  activation_961 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_961[1][0]']
#
#  batch_normalization_945 (Batch  (None, 32, 32, 128)  512        ['concatenate_574[1][0]']
#  Normalization)
#
#  conv2d_960 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_961[1][0]']
#
#  activation_945 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_945[1][0]']
#
#  concatenate_584 (Concatenate)  (None, 16, 16, 384)  0           ['concatenate_583[1][0]',
#                                                                   'conv2d_960[1][0]']
#
#  conv2d_944 (Conv2D)            (None, 32, 32, 64)   8256        ['activation_945[1][0]']
#
#  up_sampling2d_123 (UpSampling2  (None, 32, 32, 384)  0          ['concatenate_584[1][0]']
#  D)
#
#  concatenate_585 (Concatenate)  (None, 32, 32, 496)  0           ['conv2d_944[1][0]',
#                                                                   'up_sampling2d_123[1][0]',
#                                                                   'conv2d_870[1][0]',
#                                                                   'conv2d_901[1][0]',
#                                                                   'conv2d_932[1][0]']
#
#  batch_normalization_963 (Batch  (None, 32, 32, 496)  1984       ['concatenate_585[1][0]']
#  Normalization)
#
#  activation_963 (Activation)    (None, 32, 32, 496)  0           ['batch_normalization_963[1][0]']
#
#  conv2d_962 (Conv2D)            (None, 32, 32, 64)   31808       ['activation_963[1][0]']
#
#  batch_normalization_964 (Batch  (None, 32, 32, 64)  256         ['conv2d_962[1][0]']
#  Normalization)
#
#  activation_964 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_964[1][0]']
#
#  batch_normalization_941 (Batch  (None, 64, 64, 128)  512        ['concatenate_572[1][0]']
#  Normalization)
#
#  conv2d_963 (Conv2D)            (None, 32, 32, 16)   9232        ['activation_964[1][0]']
#
#  activation_941 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_941[1][0]']
#
#  concatenate_586 (Concatenate)  (None, 32, 32, 512)  0           ['concatenate_585[1][0]',
#                                                                   'conv2d_963[1][0]']
#
#  conv2d_940 (Conv2D)            (None, 64, 64, 64)   8256        ['activation_941[1][0]']
#
#  up_sampling2d_124 (UpSampling2  (None, 64, 64, 512)  0          ['concatenate_586[1][0]']
#  D)
#
#  concatenate_587 (Concatenate)  (None, 64, 64, 624)  0           ['conv2d_940[1][0]',
#                                                                   'up_sampling2d_124[1][0]',
#                                                                   'conv2d_873[1][0]',
#                                                                   'conv2d_904[1][0]',
#                                                                   'conv2d_935[1][0]']
#
#  batch_normalization_966 (Batch  (None, 64, 64, 624)  2496       ['concatenate_587[1][0]']
#  Normalization)
#
#  activation_966 (Activation)    (None, 64, 64, 624)  0           ['batch_normalization_966[1][0]']
#
#  conv2d_965 (Conv2D)            (None, 64, 64, 64)   40000       ['activation_966[1][0]']
#
#  batch_normalization_967 (Batch  (None, 64, 64, 64)  256         ['conv2d_965[1][0]']
#  Normalization)
#
#  activation_967 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_967[1][0]']
#
#  conv2d_966 (Conv2D)            (None, 64, 64, 16)   9232        ['activation_967[1][0]']
#
#  concatenate_588 (Concatenate)  (None, 64, 64, 640)  0           ['concatenate_587[1][0]',
#                                                                   'conv2d_966[1][0]']
#
#  batch_normalization_968 (Batch  (None, 64, 64, 640)  2560       ['concatenate_588[1][0]']
#  Normalization)
#
#  activation_968 (Activation)    (None, 64, 64, 640)  0           ['batch_normalization_968[1][0]']
#
#  conv2d_967 (Conv2D)            (None, 64, 64, 16)   10256       ['activation_968[1][0]']
#
# ==================================================================================================
# Total params: 1,194,512
# Trainable params: 1,164,048
# Non-trainable params: 30,464
# __________________________________________________________________________________________________
