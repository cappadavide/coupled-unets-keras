# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def getConvBlockOne(layerPrec, filters, kernel_size = (1, 1), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getConvBlockTwo(layerPrec, filters, kernel_size = (3, 3), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(filters, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getUNet(input, shape, filters):
    # CONTRACTING PHASE
  # RED block
  l1 = getConvBlockOne(input,filters)
  l1 = getConvBlockTwo(l1,filters)
  # ---
  concat1 = Concatenate()([l1,input])
  # ORANGE block
  middle1 = getConvBlockOne(concat1,filters)

  # GREEN block
  l2 = getConvBlockOne(concat1,filters)
  maxPooling1 = MaxPool2D(padding='same')(l2)
  # ---

    # Bottle neck
  l3 = getConvBlockOne(maxPooling1,filters)
  l4 = getConvBlockTwo(l3,filters)
  concat2 = Concatenate()([maxPooling1,l4])

    # EXPANSIVE PATH
  # BLUE block
  l5 = getConvBlockOne(concat2,filters)
  layer = UpSampling2D()(l5)
  layer = Conv2D(filters, kernel_size=(2,2), activation='relu', kernel_initializer='he_normal', padding='same')(layer)
  layer = BatchNormalization()(layer)
  # ---
  concat3 = Concatenate()([middle1,layer])
  
  l6 = getConvBlockOne(concat3,filters)
  l7 = getConvBlockTwo(l6,filters)
  concat4 = Concatenate()([concat3,l7])
  output = getConvBlockOne(concat4,filters)
  return Model(inputs=input, outputs=output)

def getModel(shape=(128, 128, 3), filters=64):
  # m: main feature flow
  # n: generated feature number in a block of U-Net

  input = Input(shape=shape)
  output = getUNet(input, shape, filters=64)
  return output

# %%
net = getModel(shape=(128,128,3), filters=32)
net.summary()

# %%
def getUnit1(layerPrec, m, kernel_size = (1, 1), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(m, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getUnit2(layerPrec, n, kernel_size = (3, 3), activation='relu', kernel_initializer='he_normal'):
  l = BatchNormalization()(layerPrec)
  l = Activation('relu')(l)
  l = Conv2D(n, kernel_size, kernel_initializer=kernel_initializer, padding='same')(l)
  return l

def getDownBlock(layerPrec,m,n,indexBlock):
  l = getUnit1(layerPrec,4*m)
  l = getUnit2(l,n)
  nets["layers"][f"down{indexBlock}"].append(l)

  concat = Concatenate()([layerPrec,l])
  l = getUnit1(concat,m)
  maxPooling = MaxPool2D(padding='same')(l)
  return maxPooling, getUnit1(concat,m,n)

def getUpBlock(layerPrec,skipConn,m,n,indexBlock,upLayers=[]):
  l = getUnit1(layerPrec,m)
  l = UpSampling2D()(l)
  concat = Concatenate()([skipConn,l]+upLayers)
  l = getUnit1(concat,m)
  l = getUnit2(l,n)
  nets["layers"][f"up{indexBlock}"].append(l)
  concat = Concatenate()([concat,l])
  return concat

def getUNet(input,m,n,indexUNet,nUNet, nBlocks):
  layerPrec = input
  listSkipConn = []

  if indexUNet != 0:
    layerPrec = nets[f"unet{indexUNet-1}"]
    layerPrec = Concatenate()([input,layerPrec])
    layerPrec = getUnit1(layerPrec,m)

  # down
  for i in range(nBlocks):
    layerPrec = Concatenate()([layerPrec]+nets["layers"][f"down{i}"])
    layerPrec, skipConn = getDownBlock(layerPrec,m,n,i)
    listSkipConn.append(skipConn)

  # bottle neck
  layerPrec = Concatenate()([layerPrec]+nets["layers"][f"bn"])

  l = getUnit1(layerPrec,m)
  l = getUnit2(l,n)
  nets["layers"]["bn"].append(l)
  concat = Concatenate()([layerPrec,l])

  # up
  layerPrec = concat
  for i in range(nBlocks):
    layerPrec = getUpBlock(layerPrec,listSkipConn[-(i+1)],m,n,i,upLayers=nets["layers"][f"up{i}"])


  if indexUNet != nUNet - 1:
    l = Concatenate()([input,layerPrec])
  else:
    l = getUnit1(layerPrec,16,activation=None)

  return l

def getCUNet(shape,m,n,nUNet,nBlocks):
  for i in range(nUNet):
    nets[f"unet{i}"] = None

  for j in range(nBlocks):
    nets["layers"][f"down{j}"] = []
    nets["layers"][f"up{j}"] = []
    
  input = Input(shape=shape)
  for i in range(nUNet):
    nets[f"unet{i}"] = getUNet(input,m,n,i,nUNet,nBlocks)

  output = nets[f"unet{nUNet-1}"]
  return Model(inputs=input, outputs=output)

nets = {}
nets["layers"] = {}
nets["layers"]["bn"] = []
shape = (256,256,3)
m = 64
n = 16
nUNet = 1
nBlocks = 4
net = getCUNet(shape,m,n,nUNet,nBlocks)
net.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_415 (Concatenate)  (None, 256, 256, 3)  0           ['input_17[0][0]']
#
#  batch_normalization_662 (Batch  (None, 256, 256, 3)  12         ['concatenate_415[0][0]']
#  Normalization)
#
#  activation_662 (Activation)    (None, 256, 256, 3)  0           ['batch_normalization_662[0][0]']
#
#  conv2d_662 (Conv2D)            (None, 256, 256, 25  1024        ['activation_662[0][0]']
#                                 6)
#
#  batch_normalization_663 (Batch  (None, 256, 256, 25  1024       ['conv2d_662[0][0]']
#  Normalization)                 6)
#
#  activation_663 (Activation)    (None, 256, 256, 25  0           ['batch_normalization_663[0][0]']
#                                 6)
#
#  conv2d_663 (Conv2D)            (None, 256, 256, 16  36880       ['activation_663[0][0]']
#                                 )
#
#  concatenate_416 (Concatenate)  (None, 256, 256, 19  0           ['concatenate_415[0][0]',
#                                 )                                 'conv2d_663[0][0]']
#
#  batch_normalization_664 (Batch  (None, 256, 256, 19  76         ['concatenate_416[0][0]']
#  Normalization)                 )
#
#  activation_664 (Activation)    (None, 256, 256, 19  0           ['batch_normalization_664[0][0]']
#                                 )
#
#  conv2d_664 (Conv2D)            (None, 256, 256, 64  1280        ['activation_664[0][0]']
#                                 )
#
#  max_pooling2d_88 (MaxPooling2D  (None, 128, 128, 64  0          ['conv2d_664[0][0]']
#  )                              )
#
#  concatenate_417 (Concatenate)  (None, 128, 128, 64  0           ['max_pooling2d_88[0][0]']
#                                 )
#
#  batch_normalization_666 (Batch  (None, 128, 128, 64  256        ['concatenate_417[0][0]']
#  Normalization)                 )
#
#  activation_666 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_666[0][0]']
#                                 )
#
#  conv2d_666 (Conv2D)            (None, 128, 128, 25  16640       ['activation_666[0][0]']
#                                 6)
#
#  batch_normalization_667 (Batch  (None, 128, 128, 25  1024       ['conv2d_666[0][0]']
#  Normalization)                 6)
#
#  activation_667 (Activation)    (None, 128, 128, 25  0           ['batch_normalization_667[0][0]']
#                                 6)
#
#  conv2d_667 (Conv2D)            (None, 128, 128, 16  36880       ['activation_667[0][0]']
#                                 )
#
#  concatenate_418 (Concatenate)  (None, 128, 128, 80  0           ['concatenate_417[0][0]',
#                                 )                                 'conv2d_667[0][0]']
#
#  batch_normalization_668 (Batch  (None, 128, 128, 80  320        ['concatenate_418[0][0]']
#  Normalization)                 )
#
#  activation_668 (Activation)    (None, 128, 128, 80  0           ['batch_normalization_668[0][0]']
#                                 )
#
#  conv2d_668 (Conv2D)            (None, 128, 128, 64  5184        ['activation_668[0][0]']
#                                 )
#
#  max_pooling2d_89 (MaxPooling2D  (None, 64, 64, 64)  0           ['conv2d_668[0][0]']
#  )
#
#  concatenate_419 (Concatenate)  (None, 64, 64, 64)   0           ['max_pooling2d_89[0][0]']
#
#  batch_normalization_670 (Batch  (None, 64, 64, 64)  256         ['concatenate_419[0][0]']
#  Normalization)
#
#  activation_670 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_670[0][0]']
#
#  conv2d_670 (Conv2D)            (None, 64, 64, 256)  16640       ['activation_670[0][0]']
#
#  batch_normalization_671 (Batch  (None, 64, 64, 256)  1024       ['conv2d_670[0][0]']
#  Normalization)
#
#  activation_671 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_671[0][0]']
#
#  conv2d_671 (Conv2D)            (None, 64, 64, 16)   36880       ['activation_671[0][0]']
#
#  concatenate_420 (Concatenate)  (None, 64, 64, 80)   0           ['concatenate_419[0][0]',
#                                                                   'conv2d_671[0][0]']
#
#  batch_normalization_672 (Batch  (None, 64, 64, 80)  320         ['concatenate_420[0][0]']
#  Normalization)
#
#  activation_672 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_672[0][0]']
#
#  conv2d_672 (Conv2D)            (None, 64, 64, 64)   5184        ['activation_672[0][0]']
#
#  max_pooling2d_90 (MaxPooling2D  (None, 32, 32, 64)  0           ['conv2d_672[0][0]']
#  )
#
#  concatenate_421 (Concatenate)  (None, 32, 32, 64)   0           ['max_pooling2d_90[0][0]']
#
#  batch_normalization_674 (Batch  (None, 32, 32, 64)  256         ['concatenate_421[0][0]']
#  Normalization)
#
#  activation_674 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_674[0][0]']
#
#  conv2d_674 (Conv2D)            (None, 32, 32, 256)  16640       ['activation_674[0][0]']
#
#  batch_normalization_675 (Batch  (None, 32, 32, 256)  1024       ['conv2d_674[0][0]']
#  Normalization)
#
#  activation_675 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_675[0][0]']
#
#  conv2d_675 (Conv2D)            (None, 32, 32, 16)   36880       ['activation_675[0][0]']
#
#  concatenate_422 (Concatenate)  (None, 32, 32, 80)   0           ['concatenate_421[0][0]',
#                                                                   'conv2d_675[0][0]']
#
#  batch_normalization_676 (Batch  (None, 32, 32, 80)  320         ['concatenate_422[0][0]']
#  Normalization)
#
#  activation_676 (Activation)    (None, 32, 32, 80)   0           ['batch_normalization_676[0][0]']
#
#  conv2d_676 (Conv2D)            (None, 32, 32, 64)   5184        ['activation_676[0][0]']
#
#  max_pooling2d_91 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_676[0][0]']
#  )
#
#  concatenate_423 (Concatenate)  (None, 16, 16, 64)   0           ['max_pooling2d_91[0][0]']
#
#  batch_normalization_678 (Batch  (None, 16, 16, 64)  256         ['concatenate_423[0][0]']
#  Normalization)
#
#  activation_678 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_678[0][0]']
#
#  conv2d_678 (Conv2D)            (None, 16, 16, 64)   4160        ['activation_678[0][0]']
#
#  batch_normalization_679 (Batch  (None, 16, 16, 64)  256         ['conv2d_678[0][0]']
#  Normalization)
#
#  activation_679 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_679[0][0]']
#
#  conv2d_679 (Conv2D)            (None, 16, 16, 16)   9232        ['activation_679[0][0]']
#
#  concatenate_424 (Concatenate)  (None, 16, 16, 80)   0           ['concatenate_423[0][0]',
#                                                                   'conv2d_679[0][0]']
#
#  batch_normalization_680 (Batch  (None, 16, 16, 80)  320         ['concatenate_424[0][0]']
#  Normalization)
#
#  batch_normalization_677 (Batch  (None, 32, 32, 80)  320         ['concatenate_422[0][0]']
#  Normalization)
#
#  activation_680 (Activation)    (None, 16, 16, 80)   0           ['batch_normalization_680[0][0]']
#
#  activation_677 (Activation)    (None, 32, 32, 80)   0           ['batch_normalization_677[0][0]']
#
#  conv2d_680 (Conv2D)            (None, 16, 16, 64)   5184        ['activation_680[0][0]']
#
#  conv2d_677 (Conv2D)            (None, 32, 32, 64)   1310784     ['activation_677[0][0]']
#
#  up_sampling2d_88 (UpSampling2D  (None, 32, 32, 64)  0           ['conv2d_680[0][0]']
#  )
#
#  concatenate_425 (Concatenate)  (None, 32, 32, 128)  0           ['conv2d_677[0][0]',
#                                                                   'up_sampling2d_88[0][0]']
#
#  batch_normalization_681 (Batch  (None, 32, 32, 128)  512        ['concatenate_425[0][0]']
#  Normalization)
#
#  activation_681 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_681[0][0]']
#
#  conv2d_681 (Conv2D)            (None, 32, 32, 64)   8256        ['activation_681[0][0]']
#
#  batch_normalization_682 (Batch  (None, 32, 32, 64)  256         ['conv2d_681[0][0]']
#  Normalization)
#
#  activation_682 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_682[0][0]']
#
#  conv2d_682 (Conv2D)            (None, 32, 32, 16)   9232        ['activation_682[0][0]']
#
#  concatenate_426 (Concatenate)  (None, 32, 32, 144)  0           ['concatenate_425[0][0]',
#                                                                   'conv2d_682[0][0]']
#
#  batch_normalization_683 (Batch  (None, 32, 32, 144)  576        ['concatenate_426[0][0]']
#  Normalization)
#
#  batch_normalization_673 (Batch  (None, 64, 64, 80)  320         ['concatenate_420[0][0]']
#  Normalization)
#
#  activation_683 (Activation)    (None, 32, 32, 144)  0           ['batch_normalization_683[0][0]']
#
#  activation_673 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_673[0][0]']
#
#  conv2d_683 (Conv2D)            (None, 32, 32, 64)   9280        ['activation_683[0][0]']
#
#  conv2d_673 (Conv2D)            (None, 64, 64, 64)   1310784     ['activation_673[0][0]']
#
#  up_sampling2d_89 (UpSampling2D  (None, 64, 64, 64)  0           ['conv2d_683[0][0]']
#  )
#
#  concatenate_427 (Concatenate)  (None, 64, 64, 128)  0           ['conv2d_673[0][0]',
#                                                                   'up_sampling2d_89[0][0]']
#
#  batch_normalization_684 (Batch  (None, 64, 64, 128)  512        ['concatenate_427[0][0]']
#  Normalization)
#
#  activation_684 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_684[0][0]']
#
#  conv2d_684 (Conv2D)            (None, 64, 64, 64)   8256        ['activation_684[0][0]']
#
#  batch_normalization_685 (Batch  (None, 64, 64, 64)  256         ['conv2d_684[0][0]']
#  Normalization)
#
#  activation_685 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_685[0][0]']
#
#  conv2d_685 (Conv2D)            (None, 64, 64, 16)   9232        ['activation_685[0][0]']
#
#  concatenate_428 (Concatenate)  (None, 64, 64, 144)  0           ['concatenate_427[0][0]',
#                                                                   'conv2d_685[0][0]']
#
#  batch_normalization_686 (Batch  (None, 64, 64, 144)  576        ['concatenate_428[0][0]']
#  Normalization)
#
#  batch_normalization_669 (Batch  (None, 128, 128, 80  320        ['concatenate_418[0][0]']
#  Normalization)                 )
#
#  activation_686 (Activation)    (None, 64, 64, 144)  0           ['batch_normalization_686[0][0]']
#
#  activation_669 (Activation)    (None, 128, 128, 80  0           ['batch_normalization_669[0][0]']
#                                 )
#
#  conv2d_686 (Conv2D)            (None, 64, 64, 64)   9280        ['activation_686[0][0]']
#
#  conv2d_669 (Conv2D)            (None, 128, 128, 64  1310784     ['activation_669[0][0]']
#                                 )
#
#  up_sampling2d_90 (UpSampling2D  (None, 128, 128, 64  0          ['conv2d_686[0][0]']
#  )                              )
#
#  concatenate_429 (Concatenate)  (None, 128, 128, 12  0           ['conv2d_669[0][0]',
#                                 8)                                'up_sampling2d_90[0][0]']
#
#  batch_normalization_687 (Batch  (None, 128, 128, 12  512        ['concatenate_429[0][0]']
#  Normalization)                 8)
#
#  activation_687 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_687[0][0]']
#                                 8)
#
#  conv2d_687 (Conv2D)            (None, 128, 128, 64  8256        ['activation_687[0][0]']
#                                 )
#
#  batch_normalization_688 (Batch  (None, 128, 128, 64  256        ['conv2d_687[0][0]']
#  Normalization)                 )
#
#  activation_688 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_688[0][0]']
#                                 )
#
#  conv2d_688 (Conv2D)            (None, 128, 128, 16  9232        ['activation_688[0][0]']
#                                 )
#
#  concatenate_430 (Concatenate)  (None, 128, 128, 14  0           ['concatenate_429[0][0]',
#                                 4)                                'conv2d_688[0][0]']
#
#  batch_normalization_689 (Batch  (None, 128, 128, 14  576        ['concatenate_430[0][0]']
#  Normalization)                 4)
#
#  batch_normalization_665 (Batch  (None, 256, 256, 19  76         ['concatenate_416[0][0]']
#  Normalization)                 )
#
#  activation_689 (Activation)    (None, 128, 128, 14  0           ['batch_normalization_689[0][0]']
#                                 4)
#
#  activation_665 (Activation)    (None, 256, 256, 19  0           ['batch_normalization_665[0][0]']
#                                 )
#
#  conv2d_689 (Conv2D)            (None, 128, 128, 64  9280        ['activation_689[0][0]']
#                                 )
#
#  conv2d_665 (Conv2D)            (None, 256, 256, 64  311360      ['activation_665[0][0]']
#                                 )
#
#  up_sampling2d_91 (UpSampling2D  (None, 256, 256, 64  0          ['conv2d_689[0][0]']
#  )                              )
#
#  concatenate_431 (Concatenate)  (None, 256, 256, 12  0           ['conv2d_665[0][0]',
#                                 8)                                'up_sampling2d_91[0][0]']
#
#  batch_normalization_690 (Batch  (None, 256, 256, 12  512        ['concatenate_431[0][0]']
#  Normalization)                 8)
#
#  activation_690 (Activation)    (None, 256, 256, 12  0           ['batch_normalization_690[0][0]']
#                                 8)
#
#  conv2d_690 (Conv2D)            (None, 256, 256, 64  8256        ['activation_690[0][0]']
#                                 )
#
#  batch_normalization_691 (Batch  (None, 256, 256, 64  256        ['conv2d_690[0][0]']
#  Normalization)                 )
#
#  activation_691 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_691[0][0]']
#                                 )
#
#  conv2d_691 (Conv2D)            (None, 256, 256, 16  9232        ['activation_691[0][0]']
#                                 )
#
#  concatenate_432 (Concatenate)  (None, 256, 256, 14  0           ['concatenate_431[0][0]',
#                                 4)                                'conv2d_691[0][0]']
#
#  batch_normalization_692 (Batch  (None, 256, 256, 14  576        ['concatenate_432[0][0]']
#  Normalization)                 4)
#
#  activation_692 (Activation)    (None, 256, 256, 14  0           ['batch_normalization_692[0][0]']
#                                 4)
#
#  conv2d_692 (Conv2D)            (None, 256, 256, 16  2320        ['activation_692[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 4,590,852
# Trainable params: 4,584,274
# Non-trainable params: 6,578
# __________________________________________________________________________________________________
